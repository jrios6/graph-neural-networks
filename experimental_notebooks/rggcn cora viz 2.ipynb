# %%
import torch
from torch.autograd import Variable
import torch.nn.functional as F
import torch.nn as nn
import pdb 
import time
import numpy as np
import pickle
from sklearn.metrics import confusion_matrix

import sys
import os 

seed = 42
np.random.seed(seed)

if torch.cuda.is_available():
    print('cuda available')
    dtypeFloat = torch.cuda.FloatTensor
    dtypeLong = torch.cuda.LongTensor
    torch.cuda.manual_seed(seed)
else:
    print('cuda not available')
    dtypeFloat = torch.FloatTensor
    dtypeLong = torch.LongTensor
    torch.manual_seed(seed)
    
# Helper methods for loading CORA Graph
from utils import load_data2,load_data3,accuracy
# Out:
# cuda available

# %% [markdown]
# ### Setup for Cora Dataset

# %%
# Load data (GCN)
adj, features, y_train, y_val, y_test, train_mask, val_mask, test_mask, labels = load_data3('cora')
adj = adj.toarray().astype(float)
adj += np.eye(adj.shape[0])
idx_train = np.argwhere(train_mask).reshape(-1)
idx_val = np.argwhere(val_mask).reshape(-1)
idx_test = np.argwhere(test_mask).reshape(-1)
labels = torch.LongTensor(np.where(labels)[1])

# %%
new_edges = []
for v1 in idx_train:
    for v2 in idx_train:
        if v1 != v2 and adj[v1, v2] != 1: # and labels[v1] == labels[v2]:
            new_edges.append((v1,v2))
new_edges = np.array(new_edges)

# %%
def dropin(new_edges, rate, dim=2708):
    np.random.shuffle(new_edges)
    v = new_edges.shape[0]
    E_start = np.zeros((v, dim))
    E_end = np.zeros((v, dim))
    for i in range(0, int(v*rate), 2):
        v1, v2 = new_edges[i]
        E_start[i,v1] = E_end[i,v2] = E_start[i+1,v1] = E_end[i+1,v2] = 1
    E_start = Variable(torch.from_numpy(E_start[:i+2,:]).float())
    E_end = Variable(torch.from_numpy(E_end[:i+2,:]).float())
    return E_start.cuda(), E_end.cuda()

# %%
# Load data (pyGCN)
# adj, features, labels, idx_train, idx_val, idx_test = load_data2()

# adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
# adj = adj.toarray()
# adj += np.eye(adj.shape[0])

cora_Estart = np.zeros((20000, 2708))
cora_Eend = np.zeros((20000, 2708))
cora_Eidentity = [] # idx of identity edges

# converting adjacency matrix to edge-to-start, edge-to-end vertex matrix
count = 0
for i in range(adj.shape[0]):
    for j in range(adj.shape[1]):
        if adj[i,j] == 1:
            cora_Estart[count,i] = 1
            cora_Eend[count,j] = 1
            if i == j:
                cora_Eidentity.append(count)
            count += 1
cora_Estart = cora_Estart[:count]
cora_Eend = cora_Eend[:count]

def get_cora_dataset():
    x = Variable(features, requires_grad=False)
    y = Variable(labels)
    E_start = Variable(torch.from_numpy(cora_Estart).float())
    E_end = Variable(torch.from_numpy(cora_Eend).float())
    
    return x.cuda(), y.cuda(), E_start.cuda(), E_end.cuda(), cora_Eidentity, new_edges

# %%
class OurConvNetcell(nn.Module):
    def __init__(self, dim_in, dim_out, dropout_fc=0, dropout_edge=0):
        super(OurConvNetcell, self).__init__()
    
        # conv1
        self.Ui1 = nn.Linear(dim_in, dim_out, bias=False) 
        self.Vi1 = nn.Linear(dim_in, dim_out, bias=False) 
        self.Vj1 = nn.Linear(dim_in, dim_out, bias=False)  
        self.bu1 = torch.nn.Parameter( torch.FloatTensor(dim_out), requires_grad=True )
        self.bv1 = torch.nn.Parameter( torch.FloatTensor(dim_out), requires_grad=True )
        
        self.dropout_fc = dropout_fc
        self.dropout_edge = dropout_edge
        
        # conv2
        self.Ui2 = nn.Linear(dim_out, dim_out, bias=False) 
        self.Vi2 = nn.Linear(dim_out, dim_out, bias=False) 
        self.Vj2 = nn.Linear(dim_out, dim_out, bias=False)  
        self.bu2 = torch.nn.Parameter( torch.FloatTensor(dim_out), requires_grad=True )
        self.bv2 = torch.nn.Parameter( torch.FloatTensor(dim_out), requires_grad=True )
        
        # bn1, bn2
        self.bn1 = torch.nn.BatchNorm1d(dim_out)
        self.bn2 = torch.nn.BatchNorm1d(dim_out)
        
        # resnet
        self.R = nn.Linear(dim_in, dim_out, bias=False) 
        
        # init
        self.init_weights_OurConvNetcell(dim_in, dim_out, 1)
        
         
    def init_weights_OurConvNetcell(self, dim_in, dim_out, gain):   
        # conv1
        scale = gain* np.sqrt( 2.0/ dim_in )
        self.Ui1.weight.data.uniform_(-scale, scale) 
        self.Vi1.weight.data.uniform_(-scale, scale) 
        self.Vj1.weight.data.uniform_(-scale, scale) 
        self.bu1.data.fill_(0)
        self.bv1.data.fill_(0)
        
        # conv2
        scale = gain* np.sqrt( 2.0/ dim_out )
        self.Ui2.weight.data.uniform_(-scale, scale) 
        self.Vi2.weight.data.uniform_(-scale, scale) 
        self.Vj2.weight.data.uniform_(-scale, scale) 
        self.bu2.data.fill_(0)
        self.bv2.data.fill_(0)
        
        # RN
        scale = gain* np.sqrt( 2.0/ dim_in )
        self.R.weight.data.uniform_(-scale, scale)  
        
        
    def forward(self, x, E_start, E_end):
        x = F.dropout(x, self.dropout_fc, training=self.training)
        xin = x
        
        # edge norm
        norm = torch.sum(E_end.t(), 1).reshape(-1,1)
#         norm = torch.max(norm, torch.ones(norm.shape).cuda())

        # conv1
        Uix = self.Ui1(x)  #  V x H_out
        Vix = self.Vi1(x)  #  V x H_out
        Vjx = self.Vj1(x)  #  V x H_out
        x1 = torch.mm(E_end,Vix) + torch.mm(E_start,Vjx) + self.bv1  # E x H_out
        x1 = torch.sigmoid(x1)
#         x1 = F.dropout(x1, self.dropout_fc, training=self.training)

        x2 = torch.mm(E_start, Uix)  #  E x H_out
        x = torch.mm(E_end.t(), x1*x2) + self.bu1 #  V x H_out
        
        x = torch.div(x, norm)# norm
        x = self.bn1(x) # bn1
        x = torch.nn.LeakyReLU(0.2)(x) # relu1
        
        # conv2
        Uix = self.Ui2(x)  #  V x H_out
        Vix = self.Vi2(x)  #  V x H_out
        Vjx = self.Vj2(x)  #  V x H_out
        x1 = torch.mm(E_end,Vix) + torch.mm(E_start,Vjx) + self.bv2  # E x H_out
        x1 = torch.sigmoid(x1)
#         x1 = F.dropout(x1, self.dropout_fc, training=self.training)
        
        x2 = torch.mm(E_start, Uix)  #  V x H_out        
        x = torch.mm(E_end.t(), x1*x2) + self.bu2 #  V x H_out
        
        x = torch.div(x, norm) # normalization
        
        x = self.bn2(x) # bn2
        x = x + self.R(xin) # addition
        x = torch.nn.LeakyReLU(0.2)(x) # relu2
        
        return x
        
class Graph_OurConvNet(nn.Module):
    def __init__(self, net_parameters, cora=False):
        super(Graph_OurConvNet, self).__init__()
        
        # parameters
        Voc = net_parameters['Voc']
        D = net_parameters['D']
        nb_clusters_target = net_parameters['nb_clusters_target']
        H = net_parameters['H']
        L = net_parameters['L']
        self.cora = cora
        self.dropout_fc = net_parameters['Dropout_fc']
        self.dropout_edge = net_parameters['Dropout_edge']
        self.drop_in = net_parameters['Dropout_in']
        
        # vector of hidden dimensions
        net_layers = []
        for layer in range(L):
            net_layers.append(H)
        
        # CL cells
        # NOTE: Each graph convnet cell uses *TWO* convolutional operations
        net_layers_extended = [net_parameters['features']] + net_layers 
        
        L = len(net_layers)
        list_of_gnn_cells = [] # list of NN cells
        for layer in range(L//2):
            Hin, Hout = net_layers_extended[2*layer], net_layers_extended[2*layer+2]
            list_of_gnn_cells.append(OurConvNetcell(Hin,Hout, self.dropout_fc, self.dropout_edge))
        
        # register the cells for pytorch
        self.gnn_cells = nn.ModuleList(list_of_gnn_cells)
            
        # fc
        Hfinal = net_layers_extended[-1]
        self.fc = nn.Linear(Hfinal,nb_clusters_target) 
        
        # init
        self.init_weights_Graph_OurConvNet(Voc,D,Hfinal,nb_clusters_target,1)
        
        # print
#         print('\nnb of hidden layers=',L)
#         print('dim of layers (w/ embed dim)=',net_layers_extended)      
#         print('\n')
        
        # class variables
        self.D = D
        self.L = L
        self.net_layers_extended = net_layers_extended      
        
        
    def init_weights_Graph_OurConvNet(self, Fin_enc, Fout_enc, Fin_fc, Fout_fc, gain):
        scale = gain* np.sqrt(2.0/ (Fin_fc+Fout_fc))
        self.fc.weight.data.uniform_(-scale, scale)  
        self.fc.bias.data.fill_(0)  
        
    def forward(self, x, E_start, E_end, E_identity, E_dropin):
        if self.training:
            # Edge Start+End Dropout for all layers
            num_edges = E_start.shape[0]
            dropout_idx = np.array([i for i in range(num_edges) if i not in E_identity])
            np.random.shuffle(dropout_idx)
            E_start = E_start.clone()
            E_start[dropout_idx[:int(num_edges*self.dropout_edge)]] = 0
            E_end = E_end.clone()
            E_end[dropout_idx[:int(num_edges*self.dropout_edge)]] = 0
            
            # Dropin
            D_start, D_end = dropin(E_dropin, self.drop_in)
            E_start = torch.cat((E_start, D_start), 0)
            E_end = torch.cat((E_end, D_end), 0)
            
        # convnet cells  
        for layer in range(self.L//2):
            gnn_layer = self.gnn_cells[layer]            
            x = gnn_layer(x,E_start,E_end) # V x H
            
        x = F.dropout(x, self.dropout_fc, training=self.training) #FC Dropout
        x = self.fc(x) # FC
        return x
         
    def loss(self, y, y_target, weight):
        loss = nn.CrossEntropyLoss()(y,y_target)
        return loss
       
    def update(self, lr, l2):
        update = torch.optim.Adam(self.parameters(), lr=lr, weight_decay=l2)
        return update
    
    def update_learning_rate(self, optimizer, lr):
        for param_group in optimizer.param_groups:
            param_group['lr'] = lr
        return optimizer
    
    def nb_param(self):
        return self.nb_param

# %%
def calculate_avg_accuracy(nb_classes, labels, pred_y):
    S = labels.data.cpu().numpy()
    C = np.argmax(torch.nn.Softmax(dim=1)(pred_y).data.cpu().numpy() , axis=1)
    return np.sum(S==C)/S.shape[0]

def update_lr(net, optimizer, average_loss, average_loss_old, lr, decay_rate, early_stopping, verbose):
    # Update LR if > early_stopping and avg val loss is higher
    if average_loss > average_loss_old and lr > early_stopping:
        lr /= decay_rate
        if verbose:
            print('Updating LR to %.7f' % lr)
    return net.update_learning_rate(optimizer, lr), lr

def print_results(iteration, batch_iters, avg_train_acc, running_train_loss, val_accuracy, lr, t_start):
    print('\niteration= %d, train loss(%diter)= %.3f, lr= %.7f, time(%diter)= %.2f' % 
          (iteration, batch_iters, running_train_loss/batch_iters, lr, 
           batch_iters, time.time() - t_start))
    print('val accuracy= %.3f' % (100* val_accuracy))
    print('train accuracy= %.3f' % (100* avg_train_acc))

# %%
def train(net, lr, l2, batch_iters, early_stopping, verbose=False):
    ### optimization parameters
    nb_classes = 7 
    max_iters = 1000
    decay_rate = 1.25
    SAVE_PATH = 'model_state'

    # Optimizer
    optimizer = net.update(lr, l2) 
    t_start = time.time()
    t_start_total = time.time()
    average_loss_old = torch.tensor(1e4).cuda()
    best = running_train_acc = running_train_loss = running_val_loss = 0.0
    tab_results = []
    
    features_x, train_y, E_start, E_end, E_identity, E_dropin = get_cora_dataset()

    for iteration in range(1, max_iters):  # loop over the dataset multiple times
        # forward, loss
        net.train()
        pred_y = net.forward(features_x, E_start, E_end, E_identity, E_dropin)
        loss = net.loss(pred_y[idx_train], train_y[idx_train], None) 
        train_acc = calculate_avg_accuracy(nb_classes, train_y[idx_train], pred_y[idx_train]) # training acc
        running_train_acc += train_acc    
        running_train_loss += loss.item()

        # backward, update
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        # validation eval
        net.eval()
        y_eval = net.forward(features_x, E_start, E_end, E_identity, E_dropin)
        val_loss = net.loss(y_eval[idx_val], train_y[idx_val], None) 
        running_val_loss += val_loss.item()

        # learning rate, print results
        if not iteration%batch_iters:
            val_accuracy = calculate_avg_accuracy(nb_classes, train_y[idx_val], y_eval[idx_val])
            average_val_loss = running_val_loss/ batch_iters
            avg_train_acc = running_train_acc/ batch_iters

            # update learning rate 
            if val_accuracy < avg_train_acc:
                optimizer, lr = update_lr(net, optimizer, average_val_loss, average_loss_old, 
                                          lr, decay_rate, early_stopping, verbose)

            # save intermediate results
            if val_accuracy > best:
                torch.save(net.state_dict(), SAVE_PATH)
                best = val_accuracy
            tab_results.append([iteration,average_val_loss,100* val_accuracy, time.time()-t_start_total])

            if verbose:
                print_results(iteration, batch_iters, avg_train_acc, running_train_loss, val_accuracy, lr, t_start)
            if lr < torch.tensor(early_stopping).cuda() and avg_train_acc - val_accuracy > 0.05:
                print("Early Stopping at %d. Highest Val: %.3f " % (iteration, max([tab_results[i][2] for i in range(len(tab_results))])))
                return max([tab_results[i][2] for i in range(len(tab_results))])
                break

            # reset counters
            t_start = time.time()
            running_train_acc = running_train_loss = running_val_loss = 0.0
            average_loss_old = average_val_loss
    return max([tab_results[i][2] for i in range(len(tab_results))])

# %%
features_x, _, _, _, _, _ = get_cora_dataset()

CORA = 1
net_parameters = {}
net_parameters['features'] = features_x.shape[1]
net_parameters['Voc'] = 7+1 
net_parameters['nb_clusters_target'] = 7
net_parameters['D'] = net_parameters['H'] = 50

# %% [markdown]
# ### Train

# %%
lr = 0.001
l2 = 0.005
layers = [12,14]
iters = 1
batch_iters = 20
early_stopping = 5e-5
dfc = [0.4, 0.5, 0.6, 0.7]
    
for i in range(len(layers)):
    net_parameters['L'] = layers[i]
    net_parameters['Dropout_fc'] = 0.0
    net_parameters['Dropout_edge'] = 0.0
    net_parameters['Dropout_in'] = 0.0001
    print("Setting Layers=%d, DFC=%.5f, LR=%f" % (layers[i], 0.0, lr))

    val_total = 0.
    for iteration in range(iters):
        net = Graph_OurConvNet(net_parameters, 1)
        net.cuda()
        val_total += train(net, lr, l2, batch_iters, early_stopping, verbose=True)
    print("Avg Val Accuracy", val_total)
# Out:
# Setting Layers=12, DFC=0.00000, LR=0.001000
#
# iteration= 20, train loss(20iter)= 1.279, lr= 0.0010000, time(20iter)= 23.10
# val accuracy= 12.200
# train accuracy= 70.214
# Updating LR to 0.0008000
#
# iteration= 40, train loss(20iter)= 0.307, lr= 0.0008000, time(20iter)= 21.69
# val accuracy= 12.200
# train accuracy= 96.714
# Updating LR to 0.0006400
#
# iteration= 60, train loss(20iter)= 0.069, lr= 0.0006400, time(20iter)= 22.17
# val accuracy= 15.800
# train accuracy= 99.464
#
# iteration= 80, train loss(20iter)= 0.028, lr= 0.0006400, time(20iter)= 21.41
# val accuracy= 23.800
# train accuracy= 99.893
#
# iteration= 100, train loss(20iter)= 0.024, lr= 0.0006400, time(20iter)= 20.99
# val accuracy= 40.000
# train accuracy= 99.714
#
# iteration= 120, train loss(20iter)= 0.024, lr= 0.0006400, time(20iter)= 21.16
# val accuracy= 58.200
# train accuracy= 99.607
#
# iteration= 140, train loss(20iter)= 0.022, lr= 0.0006400, time(20iter)= 21.73
# val accuracy= 61.200
# train accuracy= 99.679
# Updating LR to 0.0005120
#
# iteration= 160, train loss(20iter)= 0.023, lr= 0.0005120, time(20iter)= 18.83
# val accuracy= 62.600
# train accuracy= 99.679
#
# iteration= 180, train loss(20iter)= 0.022, lr= 0.0005120, time(20iter)= 18.67
# val accuracy= 62.000
# train accuracy= 99.714
# Updating LR to 0.0004096
#
# iteration= 200, train loss(20iter)= 0.016, lr= 0.0004096, time(20iter)= 18.66
# val accuracy= 62.000
# train accuracy= 99.786
#
# iteration= 220, train loss(20iter)= 0.019, lr= 0.0004096, time(20iter)= 18.61
# val accuracy= 60.400
# train accuracy= 99.643
# Updating LR to 0.0003277
#
# iteration= 240, train loss(20iter)= 0.017, lr= 0.0003277, time(20iter)= 18.77
# val accuracy= 60.800
# train accuracy= 99.714
#
# iteration= 260, train loss(20iter)= 0.019, lr= 0.0003277, time(20iter)= 18.65
# val accuracy= 62.800
# train accuracy= 99.643
# Updating LR to 0.0002621
#
# iteration= 280, train loss(20iter)= 0.016, lr= 0.0002621, time(20iter)= 18.82
# val accuracy= 60.200
# train accuracy= 99.714
# Updating LR to 0.0002097
#
# iteration= 300, train loss(20iter)= 0.019, lr= 0.0002097, time(20iter)= 18.72
# val accuracy= 63.200
# train accuracy= 99.714
#
# iteration= 320, train loss(20iter)= 0.018, lr= 0.0002097, time(20iter)= 18.73
# val accuracy= 62.400
# train accuracy= 99.679
#
# iteration= 340, train loss(20iter)= 0.018, lr= 0.0002097, time(20iter)= 18.72
# val accuracy= 63.000
# train accuracy= 99.750
#
# iteration= 360, train loss(20iter)= 0.015, lr= 0.0002097, time(20iter)= 18.67
# val accuracy= 63.000
# train accuracy= 99.750
# Updating LR to 0.0001678
#
# iteration= 380, train loss(20iter)= 0.011, lr= 0.0001678, time(20iter)= 18.72
# val accuracy= 62.800
# train accuracy= 99.857
# Updating LR to 0.0001342
#
# iteration= 400, train loss(20iter)= 0.026, lr= 0.0001342, time(20iter)= 18.72
# val accuracy= 62.600
# train accuracy= 99.571
#
# iteration= 420, train loss(20iter)= 0.026, lr= 0.0001342, time(20iter)= 18.73
# val accuracy= 62.600
# train accuracy= 99.571
#
# iteration= 440, train loss(20iter)= 0.018, lr= 0.0001342, time(20iter)= 18.76
# val accuracy= 65.000
# train accuracy= 99.643
# Updating LR to 0.0001074
#
# iteration= 460, train loss(20iter)= 0.017, lr= 0.0001074, time(20iter)= 18.72
# val accuracy= 63.000
# train accuracy= 99.714
#
# iteration= 480, train loss(20iter)= 0.014, lr= 0.0001074, time(20iter)= 18.64
# val accuracy= 61.800
# train accuracy= 99.786
# Updating LR to 0.0000859
#
# iteration= 500, train loss(20iter)= 0.018, lr= 0.0000859, time(20iter)= 18.65
# val accuracy= 61.200
# train accuracy= 99.643
# Updating LR to 0.0000687
#
# iteration= 520, train loss(20iter)= 0.018, lr= 0.0000687, time(20iter)= 18.67
# val accuracy= 61.600
# train accuracy= 99.679
#
# iteration= 540, train loss(20iter)= 0.019, lr= 0.0000687, time(20iter)= 18.65
# val accuracy= 62.600
# train accuracy= 99.679
# Updating LR to 0.0000550
#
# iteration= 560, train loss(20iter)= 0.019, lr= 0.0000550, time(20iter)= 18.67
# val accuracy= 62.000
# train accuracy= 99.643
#
# iteration= 580, train loss(20iter)= 0.018, lr= 0.0000550, time(20iter)= 18.66
# val accuracy= 63.000
# train accuracy= 99.750
#
# iteration= 600, train loss(20iter)= 0.017, lr= 0.0000550, time(20iter)= 18.69
# val accuracy= 64.000
# train accuracy= 99.750
#
# iteration= 620, train loss(20iter)= 0.018, lr= 0.0000550, time(20iter)= 18.68
# val accuracy= 64.200
# train accuracy= 99.679
# Updating LR to 0.0000440
#
# iteration= 640, train loss(20iter)= 0.018, lr= 0.0000440, time(20iter)= 18.65
# val accuracy= 63.400
# train accuracy= 99.643
# Early Stopping at 640. Highest Val: 65.000
# Avg Val Accuracy 65.0
# Setting Layers=14, DFC=0.00000, LR=0.001000
#
# iteration= 20, train loss(20iter)= 1.451, lr= 0.0010000, time(20iter)= 20.28
# val accuracy= 11.400
# train accuracy= 61.179
# Updating LR to 0.0008000
#
# iteration= 40, train loss(20iter)= 0.472, lr= 0.0008000, time(20iter)= 19.25
# val accuracy= 14.200
# train accuracy= 92.821
# Updating LR to 0.0006400
#
# iteration= 60, train loss(20iter)= 0.094, lr= 0.0006400, time(20iter)= 19.20
# val accuracy= 14.000
# train accuracy= 99.036
# Updating LR to 0.0005120
#
# iteration= 80, train loss(20iter)= 0.037, lr= 0.0005120, time(20iter)= 19.18
# val accuracy= 15.400
# train accuracy= 99.679
# Updating LR to 0.0004096
#
# iteration= 100, train loss(20iter)= 0.031, lr= 0.0004096, time(20iter)= 19.20
# val accuracy= 32.800
# train accuracy= 99.571
#
# iteration= 120, train loss(20iter)= 0.028, lr= 0.0004096, time(20iter)= 19.14
# val accuracy= 54.800
# train accuracy= 99.679
#
# iteration= 140, train loss(20iter)= 0.024, lr= 0.0004096, time(20iter)= 19.24
# val accuracy= 58.000
# train accuracy= 99.714
#
# iteration= 160, train loss(20iter)= 0.029, lr= 0.0004096, time(20iter)= 19.16
# val accuracy= 58.200
# train accuracy= 99.536
#
# iteration= 180, train loss(20iter)= 0.022, lr= 0.0004096, time(20iter)= 19.16
# val accuracy= 59.000
# train accuracy= 99.679
# Updating LR to 0.0003277
#
# iteration= 200, train loss(20iter)= 0.020, lr= 0.0003277, time(20iter)= 19.23
# val accuracy= 57.000
# train accuracy= 99.786
# Updating LR to 0.0002621
#
# iteration= 220, train loss(20iter)= 0.022, lr= 0.0002621, time(20iter)= 19.17
# val accuracy= 57.600
# train accuracy= 99.643
#
# iteration= 240, train loss(20iter)= 0.019, lr= 0.0002621, time(20iter)= 19.15
# val accuracy= 58.400
# train accuracy= 99.750
#
# iteration= 260, train loss(20iter)= 0.022, lr= 0.0002621, time(20iter)= 19.28
# val accuracy= 58.600
# train accuracy= 99.714
#
# iteration= 280, train loss(20iter)= 0.019, lr= 0.0002621, time(20iter)= 19.24
# val accuracy= 57.800
# train accuracy= 99.750
# Updating LR to 0.0002097
#
# iteration= 300, train loss(20iter)= 0.019, lr= 0.0002097, time(20iter)= 19.24
# val accuracy= 57.200
# train accuracy= 99.714
#
# iteration= 320, train loss(20iter)= 0.017, lr= 0.0002097, time(20iter)= 19.15
# val accuracy= 59.000
# train accuracy= 99.714
# Updating LR to 0.0001678
#
# iteration= 340, train loss(20iter)= 0.022, lr= 0.0001678, time(20iter)= 19.20
# val accuracy= 58.000
# train accuracy= 99.607
#
# iteration= 360, train loss(20iter)= 0.018, lr= 0.0001678, time(20iter)= 19.17
# val accuracy= 57.400
# train accuracy= 99.714
#
# iteration= 380, train loss(20iter)= 0.022, lr= 0.0001678, time(20iter)= 18.92
# val accuracy= 58.800
# train accuracy= 99.643
#
# iteration= 400, train loss(20iter)= 0.019, lr= 0.0001678, time(20iter)= 19.17
# val accuracy= 59.800
# train accuracy= 99.679
# Updating LR to 0.0001342
#
# iteration= 420, train loss(20iter)= 0.020, lr= 0.0001342, time(20iter)= 19.16
# val accuracy= 57.000
# train accuracy= 99.679
#
# iteration= 440, train loss(20iter)= 0.019, lr= 0.0001342, time(20iter)= 19.57
# val accuracy= 58.600
# train accuracy= 99.714
#
# iteration= 460, train loss(20iter)= 0.020, lr= 0.0001342, time(20iter)= 19.13
# val accuracy= 58.000
# train accuracy= 99.679
# Updating LR to 0.0001074
#
# iteration= 480, train loss(20iter)= 0.019, lr= 0.0001074, time(20iter)= 19.09
# val accuracy= 59.600
# train accuracy= 99.679
#
# iteration= 500, train loss(20iter)= 0.018, lr= 0.0001074, time(20iter)= 19.07
# val accuracy= 59.000
# train accuracy= 99.821
# Updating LR to 0.0000859
#
# iteration= 520, train loss(20iter)= 0.016, lr= 0.0000859, time(20iter)= 19.17
# val accuracy= 59.200
# train accuracy= 99.750
# Updating LR to 0.0000687
#
# iteration= 540, train loss(20iter)= 0.021, lr= 0.0000687, time(20iter)= 19.15
# val accuracy= 58.600
# train accuracy= 99.714
# Updating LR to 0.0000550
#
# iteration= 560, train loss(20iter)= 0.026, lr= 0.0000550, time(20iter)= 19.23
# val accuracy= 59.400
# train accuracy= 99.500
# Updating LR to 0.0000440
#
# iteration= 580, train loss(20iter)= 0.036, lr= 0.0000440, time(20iter)= 19.19
# val accuracy= 59.800
# train accuracy= 99.464
# Early Stopping at 580. Highest Val: 59.800
# Avg Val Accuracy 59.8

# %%
dfc = [0.8]
    
for i in range(len(dfc)):
    net_parameters['L'] = 4
    net_parameters['Dropout_fc'] = 0.0
    net_parameters['Dropout_edge'] = dfc[i]
    net_parameters['Dropout_in'] = 0.0001
    print("Setting Layers=%d, D_edge=%.5f, LR=%f" % (4, dfc[i], lr))

    val_total = 0.
    for iteration in range(iters):
        net = Graph_OurConvNet(net_parameters, 1)
        net.cuda()
        val_total += train(net, lr, l2, batch_iters, early_stopping, verbose=True)
    print("Avg Val Accuracy", val_total)
# Out:
# Setting Layers=4, D_edge=0.80000, LR=0.001000
#
# iteration= 20, train loss(20iter)= 0.929, lr= 0.0010000, time(20iter)= 17.59
# val accuracy= 11.400
# train accuracy= 83.214
# Updating LR to 0.0008000
#
# iteration= 40, train loss(20iter)= 0.092, lr= 0.0008000, time(20iter)= 16.96
# val accuracy= 20.000
# train accuracy= 99.429
# Updating LR to 0.0006400
#
# iteration= 60, train loss(20iter)= 0.054, lr= 0.0006400, time(20iter)= 17.08
# val accuracy= 5.800
# train accuracy= 99.393
# Updating LR to 0.0005120
#
# iteration= 80, train loss(20iter)= 0.047, lr= 0.0005120, time(20iter)= 16.98
# val accuracy= 6.000
# train accuracy= 99.393
# Updating LR to 0.0004096
#
# iteration= 100, train loss(20iter)= 0.039, lr= 0.0004096, time(20iter)= 16.96
# val accuracy= 6.000
# train accuracy= 99.500
# Updating LR to 0.0003277
#
# iteration= 120, train loss(20iter)= 0.047, lr= 0.0003277, time(20iter)= 16.86
# val accuracy= 6.000
# train accuracy= 99.393
#
# iteration= 140, train loss(20iter)= 0.046, lr= 0.0003277, time(20iter)= 16.95
# val accuracy= 31.200
# train accuracy= 99.357
#
# iteration= 160, train loss(20iter)= 0.043, lr= 0.0003277, time(20iter)= 16.97
# val accuracy= 36.200
# train accuracy= 99.286
# Updating LR to 0.0002621
#
# iteration= 180, train loss(20iter)= 0.035, lr= 0.0002621, time(20iter)= 16.94
# val accuracy= 33.800
# train accuracy= 99.464
# Updating LR to 0.0002097
#
# iteration= 200, train loss(20iter)= 0.036, lr= 0.0002097, time(20iter)= 16.99
# val accuracy= 33.400
# train accuracy= 99.429
# Updating LR to 0.0001678
#
# iteration= 220, train loss(20iter)= 0.037, lr= 0.0001678, time(20iter)= 16.87
# val accuracy= 17.200
# train accuracy= 99.393
# Updating LR to 0.0001342
#
# iteration= 240, train loss(20iter)= 0.040, lr= 0.0001342, time(20iter)= 16.87
# val accuracy= 16.600
# train accuracy= 99.321
# Updating LR to 0.0001074
#
# iteration= 260, train loss(20iter)= 0.040, lr= 0.0001074, time(20iter)= 16.87
# val accuracy= 16.200
# train accuracy= 99.357
# Updating LR to 0.0000859
#
# iteration= 280, train loss(20iter)= 0.031, lr= 0.0000859, time(20iter)= 16.87
# val accuracy= 16.200
# train accuracy= 99.464
# Updating LR to 0.0000687
#
# iteration= 300, train loss(20iter)= 0.036, lr= 0.0000687, time(20iter)= 16.86
# val accuracy= 16.200
# train accuracy= 99.357
# Updating LR to 0.0000550
#
# iteration= 320, train loss(20iter)= 0.036, lr= 0.0000550, time(20iter)= 16.86
# val accuracy= 16.200
# train accuracy= 99.357
# Updating LR to 0.0000440
#
# iteration= 340, train loss(20iter)= 0.031, lr= 0.0000440, time(20iter)= 16.86
# val accuracy= 16.200
# train accuracy= 99.429
# Early Stopping at 340. Highest Val: 36.200
# Avg Val Accuracy 36.199999999999996

# %%
dfc = [0.8]

for i in range(len(dfc)):
    net_parameters['L'] = 4
    net_parameters['Dropout_fc'] = dfc[i]
    net_parameters['Dropout_edge'] = dfc[i]
    net_parameters['Dropout_in'] = 0.0001
    print("Setting Layers=%d, D_FC=%.5f, D_edge=%.5f, LR=%f" % (4, dfc[i], dfc[i], lr))

    val_total = 0.
    for iteration in range(iters):
        net = Graph_OurConvNet(net_parameters, 1)
        net.cuda()
        val_total += train(net, lr, l2, batch_iters, early_stopping, verbose=True)
    print("Avg Val Accuracy", val_total)
# Out:
# Setting Layers=4, D_FC=0.80000, D_edge=0.80000, LR=0.001000
#
# iteration= 20, train loss(20iter)= 2.191, lr= 0.0010000, time(20iter)= 17.46
# val accuracy= 15.600
# train accuracy= 14.464
#
# iteration= 40, train loss(20iter)= 2.077, lr= 0.0010000, time(20iter)= 16.95
# val accuracy= 15.600
# train accuracy= 14.607
#
# iteration= 60, train loss(20iter)= 2.003, lr= 0.0010000, time(20iter)= 16.96
# val accuracy= 16.200
# train accuracy= 15.857
#
# iteration= 80, train loss(20iter)= 1.981, lr= 0.0010000, time(20iter)= 16.95
# val accuracy= 6.600
# train accuracy= 17.679
#
# iteration= 100, train loss(20iter)= 1.948, lr= 0.0010000, time(20iter)= 17.07
# val accuracy= 29.800
# train accuracy= 18.464
#
# iteration= 120, train loss(20iter)= 1.931, lr= 0.0010000, time(20iter)= 16.96
# val accuracy= 31.000
# train accuracy= 19.429
#
# iteration= 140, train loss(20iter)= 1.913, lr= 0.0010000, time(20iter)= 16.93
# val accuracy= 31.000
# train accuracy= 19.429
#
# iteration= 160, train loss(20iter)= 1.893, lr= 0.0010000, time(20iter)= 16.94
# val accuracy= 32.000
# train accuracy= 22.321
#
# iteration= 180, train loss(20iter)= 1.862, lr= 0.0010000, time(20iter)= 16.94
# val accuracy= 32.000
# train accuracy= 23.929
#
# iteration= 200, train loss(20iter)= 1.807, lr= 0.0010000, time(20iter)= 16.95
# val accuracy= 31.600
# train accuracy= 28.000
#
# iteration= 220, train loss(20iter)= 1.749, lr= 0.0010000, time(20iter)= 16.93
# val accuracy= 31.800
# train accuracy= 30.286
# Updating LR to 0.0008000
#
# iteration= 240, train loss(20iter)= 1.650, lr= 0.0008000, time(20iter)= 16.93
# val accuracy= 32.000
# train accuracy= 36.143
# Updating LR to 0.0006400
#
# iteration= 260, train loss(20iter)= 1.590, lr= 0.0006400, time(20iter)= 16.94
# val accuracy= 32.000
# train accuracy= 38.000
# Updating LR to 0.0005120
#
# iteration= 280, train loss(20iter)= 1.512, lr= 0.0005120, time(20iter)= 16.95
# val accuracy= 38.600
# train accuracy= 41.036
#
# iteration= 300, train loss(20iter)= 1.461, lr= 0.0005120, time(20iter)= 16.94
# val accuracy= 36.400
# train accuracy= 44.071
#
# iteration= 320, train loss(20iter)= 1.380, lr= 0.0005120, time(20iter)= 16.95
# val accuracy= 33.000
# train accuracy= 49.000
#
# iteration= 340, train loss(20iter)= 1.344, lr= 0.0005120, time(20iter)= 16.95
# val accuracy= 32.400
# train accuracy= 49.893
# Updating LR to 0.0004096
#
# iteration= 360, train loss(20iter)= 1.301, lr= 0.0004096, time(20iter)= 16.94
# val accuracy= 33.000
# train accuracy= 52.250
#
# iteration= 380, train loss(20iter)= 1.232, lr= 0.0004096, time(20iter)= 16.93
# val accuracy= 32.600
# train accuracy= 55.286
#
# iteration= 400, train loss(20iter)= 1.205, lr= 0.0004096, time(20iter)= 16.93
# val accuracy= 32.800
# train accuracy= 55.643
#
# iteration= 420, train loss(20iter)= 1.166, lr= 0.0004096, time(20iter)= 16.94
# val accuracy= 33.200
# train accuracy= 57.393
#
# iteration= 440, train loss(20iter)= 1.149, lr= 0.0004096, time(20iter)= 16.94
# val accuracy= 35.600
# train accuracy= 58.214
# Updating LR to 0.0003277
#
# iteration= 460, train loss(20iter)= 1.092, lr= 0.0003277, time(20iter)= 16.95
# val accuracy= 33.200
# train accuracy= 63.643
# Updating LR to 0.0002621
#
# iteration= 480, train loss(20iter)= 1.086, lr= 0.0002621, time(20iter)= 16.94
# val accuracy= 34.800
# train accuracy= 61.821
# Updating LR to 0.0002097
#
# iteration= 500, train loss(20iter)= 1.073, lr= 0.0002097, time(20iter)= 16.95
# val accuracy= 34.800
# train accuracy= 62.607
# Updating LR to 0.0001678
#
# iteration= 520, train loss(20iter)= 1.038, lr= 0.0001678, time(20iter)= 16.95
# val accuracy= 34.000
# train accuracy= 64.250
# Updating LR to 0.0001342
#
# iteration= 540, train loss(20iter)= 1.052, lr= 0.0001342, time(20iter)= 16.94
# val accuracy= 32.800
# train accuracy= 63.750
#
# iteration= 560, train loss(20iter)= 1.004, lr= 0.0001342, time(20iter)= 16.94
# val accuracy= 32.800
# train accuracy= 66.571
#
# iteration= 580, train loss(20iter)= 1.034, lr= 0.0001342, time(20iter)= 16.94
# val accuracy= 32.400
# train accuracy= 64.214
#
# iteration= 600, train loss(20iter)= 1.025, lr= 0.0001342, time(20iter)= 16.95
# val accuracy= 32.600
# train accuracy= 64.179
#
# iteration= 620, train loss(20iter)= 1.001, lr= 0.0001342, time(20iter)= 16.95
# val accuracy= 33.000
# train accuracy= 65.357
#
# iteration= 640, train loss(20iter)= 0.981, lr= 0.0001342, time(20iter)= 16.95
# val accuracy= 33.600
# train accuracy= 66.786
#
# iteration= 660, train loss(20iter)= 0.967, lr= 0.0001342, time(20iter)= 16.95
# val accuracy= 32.800
# train accuracy= 68.464
# Updating LR to 0.0001074
#
# iteration= 680, train loss(20iter)= 0.983, lr= 0.0001074, time(20iter)= 16.95
# val accuracy= 32.400
# train accuracy= 66.286
# Updating LR to 0.0000859
#
# iteration= 700, train loss(20iter)= 0.998, lr= 0.0000859, time(20iter)= 16.94
# val accuracy= 32.000
# train accuracy= 65.714
#
# iteration= 720, train loss(20iter)= 0.962, lr= 0.0000859, time(20iter)= 16.94
# val accuracy= 32.400
# train accuracy= 68.286
#
# iteration= 740, train loss(20iter)= 0.967, lr= 0.0000859, time(20iter)= 16.95
# val accuracy= 32.800
# train accuracy= 65.857
#
# iteration= 760, train loss(20iter)= 0.967, lr= 0.0000859, time(20iter)= 16.94
# val accuracy= 33.000
# train accuracy= 67.143
# Updating LR to 0.0000687
#
# iteration= 780, train loss(20iter)= 0.962, lr= 0.0000687, time(20iter)= 16.94
# val accuracy= 32.000
# train accuracy= 66.250
# Updating LR to 0.0000550
#
# iteration= 800, train loss(20iter)= 0.962, lr= 0.0000550, time(20iter)= 16.95
# val accuracy= 32.200
# train accuracy= 68.250
#
# iteration= 820, train loss(20iter)= 0.976, lr= 0.0000550, time(20iter)= 16.95
# val accuracy= 32.200
# train accuracy= 67.214
# Updating LR to 0.0000440
#
# iteration= 840, train loss(20iter)= 0.940, lr= 0.0000440, time(20iter)= 16.94
# val accuracy= 32.200
# train accuracy= 67.107
# Early Stopping at 840. Highest Val: 38.600
# Avg Val Accuracy 38.6
